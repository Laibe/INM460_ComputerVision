# %% [markdown]
# # DetectNum Function
# As per coursework requirements. <br>
#
# DocString:
# ```Python
# def detectNum(filename,returnimage=False):
#     '''
#     Function that detects the white A4 paper and recognises the number written on it
#     input: image or movie
#     supported formats: ['jpg','JPG','png','PNG','JPEG','jpeg','mov','MOV','mp4']
#     returnimage: optional switch that returns the image with a bounding box around the paper. This function is not available for video formats
#     '''
# ```

# %%
# import detectNum function
from ocr import detectNum

# import libraries
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image,ImageDraw
# %matplotlib inline

# %% [markdown]
# ## Examples

# %% [markdown]
# ### 1.1 Video File

# %%
detectNum('IMG_0810.mov')
# Out:
# '10'

# %% [markdown]
# ### 1.2 Image File

# %%
detectNum('indiv001.jpg')
# Out:
# ['01']

# %% [markdown]
# #### 1.2.1 Image File with two numbers
# Returns a list of numbers that were detected. Note: Since this image was created in a photo editing software it does not contain exif infos. Exif info is checked to account for images that are saved in landscape mode but are taken in portrait mode. For more details see report.

# %%
detectNum('two_indiv_numbers.jpg')
# Out:
# No exif data found, continuing without check for iPhone SE
# ['16', '03']

# %% [markdown]
# #### 1.2.2 Image File with illustration of paper detection
# This is currently only implemented for images containing one rectangle.

# %%
num, img = detectNum('indiv001.jpg',returnimage=True)
print(num)
plt.figure(figsize=(10,10))
plt.imshow(img)
# Out:
# ['01']
